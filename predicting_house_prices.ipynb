# %% [markdown]
# # 🏠 California Housing Dataset (1990)
#
# ## 📌 Overview
# The California Housing dataset contains information collected from the **1990 U.S. Census**.
# It is widely used for **regression tasks** in machine learning, where the goal is to predict housing prices.
#
# ---
#
# ## 🎯 Objective
# To predict the **median house value** in California districts based on various features like income, population, and location.
#
# ---
#
# ## 📊 Features Description
#
# - **longitude** → Geographic coordinate (east-west position)
# - **latitude** → Geographic coordinate (north-south position)
# - **housing_median_age** → Median age of houses in the area
# - **total_rooms** → Total number of rooms in all houses
# - **total_bedrooms** → Total number of bedrooms
# - **population** → Total number of people living in the area
# - **households** → Number of households
# - **median_income** → Median income of residents (in tens of thousands USD)
# - **ocean_proximity** → Categorical feature (e.g., NEAR BAY, INLAND)
#
# ---
#
# ## 🎯 Target Variable
#
# - **median_house_value** → Median price of houses (in USD)
#
# ---
#
# ## 🧠 Problem Type
# This is a **Supervised Learning – Regression Problem**, because:
# - Input data (features) are given
# - Output (house price) is continuous
#
# ---
#
# ## ⚙️ Common Steps in Analysis
#
# 1. **Data Loading**
# 2. **Exploratory Data Analysis (EDA)**
# 3. **Handling Missing Values**
# 4. **Feature Engineering**
# 5. **Encoding Categorical Data**
# 6. **Model Training (e.g., Linear Regression, Decision Tree)**
# 7. **Model Evaluation (R² Score, MAE, RMSE)**
#
# ---
#
# ## 📉 Evaluation Metrics
#
# - **MAE (Mean Absolute Error)** → Average absolute difference between predicted and actual values
# - **MSE (Mean Squared Error)** → Penalizes larger errors more
# - **RMSE (Root Mean Squared Error)** → Square root of MSE
# - **R² Score** → Measures how well the model explains variance
#
# ---
#
# ## 📌 Use Cases
#
# - Real estate price prediction
# - Economic analysis
# - Urban planning
# - Investment decision-making
#
# ---
#
# ## 🧾 Conclusion
# The California Housing dataset is a **beginner-friendly dataset** that helps in understanding:
# - Regression modeling
# - Data preprocessing
# - Feature importance
# - Model evaluation
#
# It is commonly used in machine learning tutorials and projects.

# %% [markdown]
# # Measuring Errors (RMSE & MAE)
# After training our regression model, we need to evaluate how good its predictions are. Two common metrics used for this are MAE and RMSE.
#
# # 1. Mean Absolute Error (MAE)
# MAE stands for Mean Absolute Error. It calculates the average of the absolute differences between the predicted and actual values.
#
# Formula: MAE = (1/n) × sum of |actual - predicted|
#
# It treats all errors equally, no matter their size.
# MAE is based on the Manhattan norm (also called L1 norm), which measures distance by summing absolute values.
# # 2. Root Mean Squared Error (RMSE)
# RMSE stands for Root Mean Squared Error. It calculates the square root of the average of squared differences between predicted and actual values.
#
# Formula: RMSE = sqrt((1/n) × sum of (actual - predicted)²)
#
# RMSE gives more weight to larger errors because it squares them.
# RMSE is based on the Euclidean norm (also called L2 norm), which measures straight-line distance.
#
# ## Summary
# Use MAE when all errors should be treated equally.
#
# Use RMSE when larger errors should be penalized more.
